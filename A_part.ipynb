# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets._samples_generator import make_blobs
#creating 40 separable points
X, y = make_blobs(n_samples = 100, centers = 2, random_state=20)#all the samples is 40
#fit the model, codn't reqularize for illustation purposes
clf = svm.SVC(kernel = 'linear', C=1)
clf.fit(X,y)

plt.scatter(X[:,0], X[:,1],c=y,s=30,cmap = plt.cm.Accent)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets._samples_generator import make_blobs
#creating 40 separable points
X, y = make_blobs(n_samples = 100, centers = 2, random_state=100)#all the samples is 40
#fit the model, codn't reqularize for illustation purposes
clf = svm.SVC(kernel = 'linear', C=1000)
clf.fit(X,y)
plt.scatter(X[:,0],X[:,1], c =y, s = 30,cmap=plt.cm.Accent)
#plt.show()
#plt the decision function
ax = plt.gca()# shib -> finding axes
xlim = ax.get_xlim()#show the start point to the end point 
ylim = ax.get_ylim()
print(xlim)
print(ylim)
#create gird to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)#create 30 part from start poiont to end point
yy = np.linspace(ylim[0], ylim[1], 30)
# print(xx)
# print(yy)
YY, XX = np.meshgrid(yy, xx)#create matric -> like a chess
print(XX[0])
print(YY[0])
xy = np.vstack([XX.ravel(),YY.ravel()]).T#compine all of them (1,1),(1,2)
Z = clf.decision_function(xy).reshape(XX.shape)
#plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1],alpha=0.5, linestyles=['--','-','--'])
#plot support vectors
ax.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1], s=100, linewidth = 1, facecolors = 'none')
plt.show()
# Out:
# (-3.8462140671130705, 3.2240835622974475)
# (-7.714413768946604, 9.767884814248033)
# [-3.84621407 -3.84621407 -3.84621407 -3.84621407 -3.84621407 -3.84621407
#  -3.84621407 -3.84621407 -3.84621407 -3.84621407 -3.84621407 -3.84621407
#  -3.84621407 -3.84621407 -3.84621407 -3.84621407 -3.84621407 -3.84621407
#  -3.84621407 -3.84621407 -3.84621407 -3.84621407 -3.84621407 -3.84621407
#  -3.84621407 -3.84621407 -3.84621407 -3.84621407 -3.84621407 -3.84621407]
# [-7.71441377 -7.11157589 -6.508738   -5.90590012 -5.30306224 -4.70022436
#  -4.09738648 -3.49454859 -2.89171071 -2.28887283 -1.68603495 -1.08319706
#  -0.48035918  0.1224787   0.72531658  1.32815446  1.93099235  2.53383023
#   3.13666811  3.73950599  4.34234387  4.94518176  5.54801964  6.15085752
#   6.7536954   7.35653329  7.95937117  8.56220905  9.16504693  9.76788481]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets._samples_generator import make_blobs
#creating 40 separable points
X, y = make_blobs(n_samples = 100, centers = 2, random_state=5)#all the samples is 40
#fit the model, codn't reqularize for illustation purposes
clf = svm.SVC(kernel = 'rbf', C=1000)
clf.fit(X,y)
plt.scatter(X[:,0],X[:,1], c =y, s = 30,cmap=plt.cm.Accent)
#plt.show()
#plt the decision function
ax = plt.gca()# finding axes
xlim = ax.get_xlim()#show the start point to the end point 
ylim = ax.get_ylim()
print(xlim)
print(ylim)
#create gird to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)#create 30 part from start poiont to end point
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)#create matric -> like a chess
xy = np.vstack([XX.ravel(),YY.ravel()]).T#compine all of them (1,1),(1,2)
Z = clf.decision_function(xy).reshape(XX.shape)
#plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1],alpha=0.5, linestyles=['--','-','--'])
#plot support vectors
ax.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1], s=100, linewidth = 1, facecolors = 'none')
plt.show()
# Out:
# (-8.684347502509283, -2.8648424335159133)
# (5.7401451454523365, 11.138401061840142)

# %%
import numpy
import matplotlib.pyplot as plt
from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice
from sklearn import svm

X,y = datasets.make_circles(500,factor=0.5,noise=0.05)

plt.scatter(X[:,0], X[:,1], c=y, s=30, cmap=plt.cm.Accent)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets._samples_generator import make_blobs
#creating 40 separable points
X,y = datasets.make_circles(500,factor=0.5,noise=0.05)
#fit the model, codn't reqularize for illustation purposes
clf = svm.SVC(kernel = 'poly', C=1000)
clf.fit(X,y)
plt.scatter(X[:,0],X[:,1], c =y, s = 30,cmap=plt.cm.Accent)
#plt.show()
#plt the decision function
ax = plt.gca()# finding axes
xlim = ax.get_xlim()#show the start point to the end point 
ylim = ax.get_ylim()
print(xlim)
print(ylim)
#create gird to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)#create 30 part from start poiont to end point
yy = np.linspace(ylim[0], ylim[1], 30)
# print(xx)
# print(yy)
YY, XX = np.meshgrid(yy, xx)#create matric -> like a chess
print(XX[0])
print(YY[0])
xy = np.vstack([XX.ravel(),YY.ravel()]).T#compine all of them (1,1),(1,2)
Z = clf.decision_function(xy).reshape(XX.shape)
#plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1],alpha=0.5, linestyles=['--','-','--'])
#plot support vectors
ax.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1], s=100, linewidth = 1, facecolors = 'none')
plt.show()
# Out:
# (-1.1810650025351404, 1.241190824620614)
# (-1.2224273053871968, 1.2218641571479887)
# [-1.181065 -1.181065 -1.181065 -1.181065 -1.181065 -1.181065 -1.181065
#  -1.181065 -1.181065 -1.181065 -1.181065 -1.181065 -1.181065 -1.181065
#  -1.181065 -1.181065 -1.181065 -1.181065 -1.181065 -1.181065 -1.181065
#  -1.181065 -1.181065 -1.181065 -1.181065 -1.181065 -1.181065 -1.181065
#  -1.181065 -1.181065]
# [-1.22242731 -1.13814139 -1.05385548 -0.96956957 -0.88528366 -0.80099774
#  -0.71671183 -0.63242592 -0.54814001 -0.46385409 -0.37956818 -0.29528227
#  -0.21099636 -0.12671044 -0.04242453  0.04186138  0.12614729  0.21043321
#   0.29471912  0.37900503  0.46329094  0.54757686  0.63186277  0.71614868
#   0.80043459  0.88472051  0.96900642  1.05329233  1.13757824  1.22186416]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets._samples_generator import make_blobs
#creating 40 separable points
X,y = datasets.make_circles(500,factor=0.5,noise=0.05)
#fit the model, codn't reqularize for illustation purposes
clf = svm.SVC(kernel = 'rbf', C=1000)
clf.fit(X,y)
plt.scatter(X[:,0],X[:,1], c =y, s = 30,cmap=plt.cm.Accent)
#plt.show()
#plt the decision function
ax = plt.gca()# finding axes
xlim = ax.get_xlim()#show the start point to the end point 
ylim = ax.get_ylim()
print(xlim)
print(ylim)
#create gird to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)#create 30 part from start poiont to end point
yy = np.linspace(ylim[0], ylim[1], 30)
# print(xx)
# print(yy)
YY, XX = np.meshgrid(yy, xx)#create matric -> like a chess
print(XX[0])
print(YY[0])
xy = np.vstack([XX.ravel(),YY.ravel()]).T#compine all of them (1,1),(1,2)
Z = clf.decision_function(xy).reshape(XX.shape)
#plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1],alpha=0.5, linestyles=['--','-','--'])
#plot support vectors
ax.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1], s=100, linewidth = 1, facecolors = 'none')
plt.show()
# Out:
# (-1.1992394120639995, 1.2078486152813803)
# (-1.1798610556488665, 1.2099149593042102)
# [-1.19923941 -1.19923941 -1.19923941 -1.19923941 -1.19923941 -1.19923941
#  -1.19923941 -1.19923941 -1.19923941 -1.19923941 -1.19923941 -1.19923941
#  -1.19923941 -1.19923941 -1.19923941 -1.19923941 -1.19923941 -1.19923941
#  -1.19923941 -1.19923941 -1.19923941 -1.19923941 -1.19923941 -1.19923941
#  -1.19923941 -1.19923941 -1.19923941 -1.19923941 -1.19923941 -1.19923941]
# [-1.17986106 -1.09745499 -1.01504892 -0.93264285 -0.85023678 -0.76783071
#  -0.68542464 -0.60301857 -0.5206125  -0.43820643 -0.35580036 -0.27339429
#  -0.19098822 -0.10858215 -0.02617608  0.05622999  0.13863606  0.22104213
#   0.3034482   0.38585426  0.46826033  0.5506664   0.63307247  0.71547854
#   0.79788461  0.88029068  0.96269675  1.04510282  1.12750889  1.20991496]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets._samples_generator import make_blobs
#creating 40 separable points
X,y = datasets.make_moons(500,noise=0.05)
#fit the model, codn't reqularize for illustation purposes
clf = svm.SVC(kernel = 'rbf', C=1000)
# clf = svm.SVC(kernel = 'poly', C=1000)
clf.fit(X,y)
plt.scatter(X[:,0],X[:,1], c =y, s = 30,cmap=plt.cm.Accent)
#plt.show()
#plt the decision function
ax = plt.gca()# finding axes
xlim = ax.get_xlim()#show the start point to the end point 
ylim = ax.get_ylim()
print(xlim)
print(ylim)
#create gird to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)#create 30 part from start poiont to end point
yy = np.linspace(ylim[0], ylim[1], 30)
# print(xx)
# print(yy)
YY, XX = np.meshgrid(yy, xx)#create matric -> like a chess
print(XX[0])
print(YY[0])
xy = np.vstack([XX.ravel(),YY.ravel()]).T#compine all of them (1,1),(1,2)
Z = clf.decision_function(xy).reshape(XX.shape)
#plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1],alpha=0.5, linestyles=['--','-','--'])
#plot support vectors
ax.scatter(clf.support_vectors_[:,0],clf.support_vectors_[:,1], s=100, linewidth = 1, facecolors = 'none')
plt.show()
# Out:
# (-1.2357714465702399, 2.2414069970892956)
# (-0.6652717487739106, 1.188167638953181)
# [-1.23577145 -1.23577145 -1.23577145 -1.23577145 -1.23577145 -1.23577145
#  -1.23577145 -1.23577145 -1.23577145 -1.23577145 -1.23577145 -1.23577145
#  -1.23577145 -1.23577145 -1.23577145 -1.23577145 -1.23577145 -1.23577145
#  -1.23577145 -1.23577145 -1.23577145 -1.23577145 -1.23577145 -1.23577145
#  -1.23577145 -1.23577145 -1.23577145 -1.23577145 -1.23577145 -1.23577145]
# [-0.66527175 -0.60136005 -0.53744834 -0.47353664 -0.40962494 -0.34571323
#  -0.28180153 -0.21788983 -0.15397812 -0.09006642 -0.02615472  0.03775698
#   0.10166869  0.16558039  0.22949209  0.2934038   0.3573155   0.4212272
#   0.48513891  0.54905061  0.61296231  0.67687401  0.74078572  0.80469742
#   0.86860912  0.93252083  0.99643253  1.06034423  1.12425594  1.18816764]
